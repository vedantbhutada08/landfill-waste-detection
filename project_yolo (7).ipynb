# %%
from ultralytics import YOLO
import ipywidgets as widgets
from IPython.display import display, clear_output
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Define classes for biodegradable and non-biodegradable waste
biodegradable_classes = ['coloured_paper', 'corrugated_cardboard', 'mixed_cardboard_-cww-', 'white_paper']
non_biodegradable_classes = ['alu_foil', 'cat_food_cans', 'clear_plastic', 'food_cans', 'glass', 'hdpe_clear', 'hdpe_color', 'pet_clear-blue', 'pet_coloured', 'polypropelene', 'polystyrene_-Food trays-', 'polystyrene_-other-', 'tetra-pak', 'thermoforms', 'universal_beverage_cans', 'wte_-non-recyclable_plastic-']

# Load YOLO model with the "best.pt" file
model = YOLO("/content/best (1).pt")

# Information about biodegradable and non-biodegradable waste
biodegradable_info = """
Biodegradable waste consists of organic materials that can decompose naturally. Examples include:
- Paper products (newspapers, cardboard, etc.)
- Food waste (fruits, vegetables, etc.)
- Yard waste (grass clippings, leaves, etc.)

Proper disposal methods for biodegradable waste include composting and recycling.
Biodegradable waste can decompose aerobically or anaerobically, producing either carbon dioxide and water or methane gas.
"""

non_biodegradable_info = """
Non-biodegradable waste consists of materials that do not decompose or decompose very slowly in the environment. Examples include:
- Plastics (bottles, bags, etc.)
- Metals (aluminum foil, cans, etc.)
- Glass
- Styrofoam

Proper disposal methods for non-biodegradable waste include recycling, incineration, and landfill disposal.
Non-biodegradable waste can persist in the environment for hundreds or even thousands of years, contributing to pollution and harming wildlife.
"""

def detect_waste(image_path):
    try:
        results = model.predict(image_path)
        return results
    except Exception as e:
        print(f"An error occurred: {str(e)}")
        return None

def process_image(image_path):
    results = detect_waste(image_path)
    if results:
        biodegradable_count = 0
        non_biodegradable_count = 0

        image = Image.open(image_path)
        fig, ax = plt.subplots()
        ax.imshow(image)

        for box in results[0].boxes:
            class_id = results[0].names[box.cls[0].item()]

            if class_id in biodegradable_classes:
                biodegradable_count += 1
                border_color = 'g'
                label = "Biodegradable"
            elif class_id in non_biodegradable_classes:
                non_biodegradable_count += 1
                border_color = 'r'
                label = "Non-biodegradable"
            else:
                border_color = 'none'
                label = "Unknown"

            # Draw bounding box
            cords = box.xyxy[0].tolist()
            x_min, y_min, x_max, y_max = cords[0], cords[1], cords[2], cords[3]
            rect = patches.Rectangle((x_min, y_min), x_max - x_min, y_max - y_min, linewidth=1, edgecolor=border_color, facecolor='none')
            ax.add_patch(rect)

            # Add label to the bounding box
            ax.text(x_min, y_min - 5, label, color=border_color)

        # Display information about detected waste
        display_info(biodegradable_count, non_biodegradable_count)

        plt.show()

def display_info(biodegradable_count, non_biodegradable_count):
    print("Detected Biodegradable Waste:", biodegradable_count)
    print(biodegradable_info)
    print("Detected Non-biodegradable Waste:", non_biodegradable_count)
    print(non_biodegradable_info)

def on_select_image_button_clicked(b):
    process_image(image_path_text.value)

# Create GUI widgets
select_image_button = widgets.Button(description="Select Image")
select_image_button.on_click(on_select_image_button_clicked)

image_path_text = widgets.Text(placeholder="Enter image path")

# Display GUI
display(widgets.VBox([image_path_text, select_image_button]))
# Out:
# ...
# image 1/1 /content/drive/MyDrive/Aniopestra.v4i.yolov8/test/images/frame_002400_PNG.rf.f68c871461e01ba22041a95a01060cb6.jpg: 384x640 1 alu_foil, 2 clear_plastics, 2 coloured_papers, 1 food_cans, 3 pet_clear-blues, 1 polystyrene_-Food trays-, 1 polystyrene_-other-, 1 universal_beverage_cans, 1 white_paper, 12 wte_-non-recyclable_plastic-s, 26.2ms
# Speed: 2.0ms preprocess, 26.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Detected Biodegradable Waste: 3
#
# Biodegradable waste consists of organic materials that can decompose naturally. Examples include:
# - Paper products (newspapers, cardboard, etc.)
# - Food waste (fruits, vegetables, etc.)
# - Yard waste (grass clippings, leaves, etc.)
#
# Proper disposal methods for biodegradable waste include composting and recycling.
# Biodegradable waste can decompose aerobically or anaerobically, producing either carbon dioxide and water or methane gas.
#
# Detected Non-biodegradable Waste: 22
#
# ...

# %%
from ultralytics import YOLO
import ipywidgets as widgets
from IPython.display import display, clear_output
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Define classes for biodegradable and non-biodegradable waste
biodegradable_classes = ['coloured_paper', 'corrugated_cardboard', 'mixed_cardboard_-cww-', 'white_paper']
non_biodegradable_classes = ['alu_foil', 'cat_food_cans', 'clear_plastic', 'food_cans', 'glass', 'hdpe_clear', 'hdpe_color', 'pet_clear-blue', 'pet_coloured', 'polypropelene', 'polystyrene_-Food trays-', 'polystyrene_-other-', 'tetra-pak', 'thermoforms', 'universal_beverage_cans', 'wte_-non-recyclable_plastic-']

# Load YOLO model with the "best.pt" file
model = YOLO("/content/best (1).pt")

# Information about biodegradable and non-biodegradable waste
biodegradable_info = """
Biodegradable waste consists of organic materials that can decompose naturally. Examples include:
- Paper products (newspapers, cardboard, etc.)
- Food waste (fruits, vegetables, etc.)
- Yard waste (grass clippings, leaves, etc.)

Proper disposal methods for biodegradable waste include composting and recycling.
Biodegradable waste can decompose aerobically or anaerobically, producing either carbon dioxide and water or methane gas.
"""

non_biodegradable_info = """
Non-biodegradable waste consists of materials that do not decompose or decompose very slowly in the environment. Examples include:
- Plastics (bottles, bags, etc.)
- Metals (aluminum foil, cans, etc.)
- Glass
- Styrofoam

Proper disposal methods for non-biodegradable waste include recycling, incineration, and landfill disposal.
Non-biodegradable waste can persist in the environment for hundreds or even thousands of years, contributing to pollution and harming wildlife.
"""

def detect_waste(image_path):
    try:
        results = model.predict(image_path)
        return results
    except Exception as e:
        print(f"An error occurred: {str(e)}")
        return None

def process_image(image_path):
    results = detect_waste(image_path)
    if results:
        biodegradable_count = 0
        non_biodegradable_count = 0

        image = Image.open(image_path)
        fig, ax = plt.subplots()
        ax.imshow(image)

        for box in results[0].boxes:
            class_id = results[0].names[box.cls[0].item()]

            if class_id in biodegradable_classes:
                biodegradable_count += 1
                border_color = 'g'
            elif class_id in non_biodegradable_classes:
                non_biodegradable_count += 1
                border_color = 'r'
            else:
                border_color = 'none'

            # Draw bounding box
            cords = box.xyxy[0].tolist()
            x_min, y_min, x_max, y_max = cords[0], cords[1], cords[2], cords[3]
            rect = patches.Rectangle((x_min, y_min), x_max - x_min, y_max - y_min, linewidth=1, edgecolor=border_color, facecolor='none')
            ax.add_patch(rect)

        # Display information about detected waste
        display_info(biodegradable_count, non_biodegradable_count)

        plt.show()

def display_info(biodegradable_count, non_biodegradable_count):
    print("Detected Biodegradable Waste:", biodegradable_count)
    print(biodegradable_info)
    print("Detected Non-biodegradable Waste:", non_biodegradable_count)
    print(non_biodegradable_info)

def on_select_image_button_clicked(b):
    process_image(image_path_text.value)

# Create GUI widgets
select_image_button = widgets.Button(description="Select Image")
select_image_button.on_click(on_select_image_button_clicked)

image_path_text = widgets.Text(placeholder="Enter image path")

# Display GUI
display(widgets.VBox([image_path_text, select_image_button]))
# Out:
# ...
# image 1/1 /content/drive/MyDrive/Aniopestra.v4i.yolov8/test/images/frame_002400_PNG.rf.f68c871461e01ba22041a95a01060cb6.jpg: 384x640 1 alu_foil, 2 clear_plastics, 2 coloured_papers, 1 food_cans, 3 pet_clear-blues, 1 polystyrene_-Food trays-, 1 polystyrene_-other-, 1 universal_beverage_cans, 1 white_paper, 12 wte_-non-recyclable_plastic-s, 26.2ms
# Speed: 1.9ms preprocess, 26.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Detected Biodegradable Waste: 3
#
# Biodegradable waste consists of organic materials that can decompose naturally. Examples include:
# - Paper products (newspapers, cardboard, etc.)
# - Food waste (fruits, vegetables, etc.)
# - Yard waste (grass clippings, leaves, etc.)
#
# Proper disposal methods for biodegradable waste include composting and recycling.
# Biodegradable waste can decompose aerobically or anaerobically, producing either carbon dioxide and water or methane gas.
#
# Detected Non-biodegradable Waste: 22
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 749.6/749.6 kB 4.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 31.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 66.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 56.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 1.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 2.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 2.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 1.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 2.7 MB/s eta 0:00:00
# ...

# %%
# %pip install ultralytics
from ultralytics import YOLO

# %%
model = YOLO("yolov8m.pt")
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 285MB/s]

# %%
model.train(data="/content/drive/MyDrive/Aniopestra.v4i.yolov8/data.yaml", epochs=150)
# Out:
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
infer = YOLO("/content/runs/detect/train/weights/best.pt")

# %%
results = infer.predict("/content/drive/MyDrive/Aniopestra.v4i.yolov8/test/images/frame_000096_PNG.rf.43c579a5fffce3ec40d77422f87570c4.jpg")
# Out:
# image 1/1 /content/drive/MyDrive/Aniopestra.v4i.yolov8/test/images/frame_000096_PNG.rf.43c579a5fffce3ec40d77422f87570c4.jpg: 384x640 1 cat_food_cans, 1 clear_plastic, 2 coloured_papers, 1 hdpe_clear, 1 pet_clear-blue, 1 polypropelene, 7 polystyrene_-other-s, 1 tetra-pak, 2 thermoformss, 3 universal_beverage_canss, 4 white_papers, 17 wte_-non-recyclable_plastic-s, 27.3ms
# Speed: 2.5ms preprocess, 27.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)

# %%
result = results[0]

# %%
print(len(result.boxes))
# Out:
# 41

# %%
box = result.boxes[0]
print("Object Type : ", box.cls)
# Out:
# Object Type :  tensor([14.], device='cuda:0')

# %%
print("Object type:", box.cls)
print("Coordinates:", box.xyxy)
print("Probability:", box.conf)
print("Object type:",box.cls[0])
print("Coordinates:",box.xyxy[0])
print("Probability:",box.conf[0])
# Out:
# Object type: tensor([14.], device='cuda:0')
# Coordinates: tensor([[326.5410, 357.1367, 548.8887, 576.3062]], device='cuda:0')
# Probability: tensor([0.9578], device='cuda:0')
# Object type: tensor(14., device='cuda:0')
# Coordinates: tensor([326.5410, 357.1367, 548.8887, 576.3062], device='cuda:0')
# Probability: tensor(0.9578, device='cuda:0')

# %%
cords = box.xyxy[0].tolist()
class_id = box.cls[0].item()
conf = box.conf[0].item()
print("Object type:", class_id)
print("Coordinates:", cords)
print("Probability:", conf)
# Out:
# Object type: 14.0
# Coordinates: [326.54095458984375, 357.13671875, 548.8887329101562, 576.3062133789062]
# Probability: 0.9578254222869873

# %%
print(result.names)
# Out:
# {0: 'alu_foil', 1: 'cat_food_cans', 2: 'clear_plastic', 3: 'coloured_paper', 4: 'corrugated_cardboard', 5: 'food_cans', 6: 'glass', 7: 'hdpe_clear', 8: 'hdpe_color', 9: 'mixed_cardboard_-cww-', 10: 'pet_clear-blue', 11: 'pet_coloured', 12: 'polypropelene', 13: 'polystyrene_-Food trays-', 14: 'polystyrene_-other-', 15: 'tetra-pak', 16: 'thermoforms', 17: 'universal_beverage_cans', 18: 'white_paper', 19: 'wte_-non-recyclable_plastic-'}

# %%
cords = box.xyxy[0].tolist()
cords = [round(x) for x in cords]
class_id = result.names[box.cls[0].item()]
conf = round(box.conf[0].item(), 2)
print("Object type:", class_id)
print("Coordinates:", cords)
print("Probability:", conf)
# Out:
# Object type: polystyrene_-other-
# Coordinates: [327, 357, 549, 576]
# Probability: 0.96

# %%
for box in result.boxes:
  class_id = result.names[box.cls[0].item()]
  cords = box.xyxy[0].tolist()
  cords = [round(x) for x in cords]
  conf = round(box.conf[0].item(), 2)
  print("Object type:", class_id)
  print("Coordinates:", cords)
  print("Probability:", conf)
  print("---")
# Out:
# Object type: polystyrene_-other-
# Coordinates: [327, 357, 549, 576]
# Probability: 0.96
# ---
# Object type: polystyrene_-other-
# Coordinates: [296, 44, 417, 158]
# Probability: 0.96
# ---
# Object type: universal_beverage_cans
# Coordinates: [546, 274, 644, 358]
# Probability: 0.95
# ---
# Object type: polystyrene_-other-
# Coordinates: [223, 494, 309, 570]
# Probability: 0.95
# ---
# Object type: tetra-pak
# Coordinates: [772, 38, 965, 215]
# Probability: 0.95
# ---
# Object type: white_paper
# Coordinates: [166, 473, 257, 576]
# Probability: 0.94
# ---
# Object type: white_paper
# Coordinates: [294, 267, 465, 358]
# Probability: 0.94
# ---
# Object type: polystyrene_-other-
# Coordinates: [831, 370, 940, 471]
# Probability: 0.94
# ---
# Object type: wte_-non-recyclable_plastic-
# Coordinates: [694, 42, 798, 164]
# Probability: 0.94
# ---
# Object type: white_paper
# Coordinates: [590, 308, 715, 412]
# Probability: 0.94
# ---
# Object type: wte_-non-recyclable_plastic-
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image

# Load the image
image_path = "/content/drive/MyDrive/Aniopestra.v4i.yolov8/test/images/frame_000096_PNG.rf.43c579a5fffce3ec40d77422f87570c4.jpg"
image = Image.open(image_path)

# Create figure and axes
fig, ax = plt.subplots()

# Display the image
ax.imshow(image)

# Iterate over each detected box
for box in result.boxes:
    class_id = result.names[box.cls[0].item()]
    cords = box.xyxy[0].tolist()
    cords = [round(x) for x in cords]
    conf = round(box.conf[0].item(), 2)

    # Define coordinates of the box [x_min, y_min, width, height]
    x_min, y_min, x_max, y_max = cords
    width = x_max - x_min
    height = y_max - y_min

    # Create a Rectangle patch
    rect = patches.Rectangle((x_min, y_min), width, height, linewidth=1, edgecolor='r', facecolor='none')

    # Add the patch to the Axes
    ax.add_patch(rect)

    # Show object type and confidence score
    ax.text(x_min, y_min, f"{class_id} ({conf})", color='r', verticalalignment='top')

# Show plot
plt.show()

# %%
infer = YOLO("/content/best (1).pt")

# %%
results = infer.predict("/content/drive/MyDrive/Aniopestra.v4i.yolov8/test/images/frame_002400_PNG.rf.f68c871461e01ba22041a95a01060cb6.jpg")
# Out:
# image 1/1 /content/drive/MyDrive/Aniopestra.v4i.yolov8/test/images/frame_002400_PNG.rf.f68c871461e01ba22041a95a01060cb6.jpg: 384x640 1 alu_foil, 2 clear_plastics, 2 coloured_papers, 1 food_cans, 3 pet_clear-blues, 1 polystyrene_-Food trays-, 1 polystyrene_-other-, 1 universal_beverage_cans, 1 white_paper, 12 wte_-non-recyclable_plastic-s, 25.3ms
# Speed: 2.1ms preprocess, 25.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)

# %%
# Mapping of classes to their corresponding categories
biodegradable_classes = ['coloured_paper', 'corrugated_cardboard', 'mixed_cardboard_-cww-', 'white_paper']
non_biodegradable_classes = ['alu_foil', 'cat_food_cans', 'clear_plastic', 'food_cans', 'glass', 'hdpe_clear', 'hdpe_color', 'pet_clear-blue', 'pet_coloured', 'polypropelene', 'polystyrene_-Food trays-', 'polystyrene_-other-', 'tetra-pak', 'thermoforms', 'universal_beverage_cans', 'wte_-non-recyclable_plastic-']

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image

# Load the image
image_path = "/content/drive/MyDrive/Aniopestra.v4i.yolov8/test/images/frame_002400_PNG.rf.f68c871461e01ba22041a95a01060cb6.jpg"
image = Image.open(image_path)

# Create figure and axes
fig, ax = plt.subplots()

# Display the image
ax.imshow(image)

# Iterate over each detected box
for box in results[0].boxes:
    class_id = results[0].names[box.cls[0].item()]
    cords = box.xyxy[0].tolist()
    cords = [round(x) for x in cords]
    conf = round(box.conf[0].item(), 2)

    # Define coordinates of the box [x_min, y_min, width, height]
    x_min, y_min, x_max, y_max = cords
    width = x_max - x_min
    height = y_max - y_min

    # Determine category
    if class_id in biodegradable_classes:
        category = 'Bio-degradable'
        border_color = 'g'  # Green border for biodegradable
        text_color = 'g'  # Green text for biodegradable
    elif class_id in non_biodegradable_classes:
        category = 'Non-biodegradable'
        border_color = 'r'  # Red border for non-biodegradable
        text_color = 'r'  # Red text for non-biodegradable
    else:
        category = 'Unknown'
        border_color = 'none'
        text_color = 'black'  # Default text color

    # Create a Rectangle patch with border color only
    rect = patches.Rectangle((x_min, y_min), width, height, linewidth=1, edgecolor=border_color, facecolor='none')

    # Add the patch to the Axes
    ax.add_patch(rect)

    # Show object category and confidence score
    ax.text(x_min, y_min, f"{category} ({conf})", color=text_color, verticalalignment='top')

# Show plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# True positive (TP), False positive (FP), True negative (TN), False negative (FN) values
biodegradable_TP = 806
biodegradable_FP = 151
non_biodegradable_TP = 5262
non_biodegradable_FP = 993

# Calculate False Negative (FN) values
biodegradable_FN = biodegradable_FP
non_biodegradable_FN = biodegradable_FP

# Create confusion matrix
conf_matrix = np.array([[biodegradable_TP, biodegradable_FN],
                        [non_biodegradable_FP, non_biodegradable_TP]])

# Define class labels
classes = ['Biodegradable', 'Non-biodegradable']

# Plot confusion matrix
plt.imshow(conf_matrix, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)

# Display values in each cell
for i in range(len(classes)):
    for j in range(len(classes)):
        plt.text(j, i, str(conf_matrix[i][j]), ha='center', va='center', color='red')

plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %%
# Mapping of classes to their corresponding categories
biodegradable_classes = ['coloured_paper', 'corrugated_cardboard', 'mixed_cardboard_-cww-', 'white_paper']
non_biodegradable_classes = ['alu_foil', 'cat_food_cans', 'clear_plastic', 'food_cans', 'glass', 'hdpe_clear', 'hdpe_color', 'pet_clear-blue', 'pet_coloured', 'polypropelene', 'polystyrene_-Food trays-', 'polystyrene_-other-', 'tetra-pak', 'thermoforms', 'universal_beverage_cans', 'wte_-non-recyclable_plastic-']

import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image

# Load the image
image_path = "/content/drive/MyDrive/Aniopestra.v4i.yolov8/test/images/frame_000096_PNG.rf.43c579a5fffce3ec40d77422f87570c4.jpg"
image = Image.open(image_path)

# Create figure and axes
fig, ax = plt.subplots()

# Display the image
ax.imshow(image)

# Iterate over each detected box
for box in results[0].boxes:
    class_id = results[0].names[box.cls[0].item()]
    cords = box.xyxy[0].tolist()
    cords = [round(x) for x in cords]
    conf = round(box.conf[0].item(), 2)

    # Define coordinates of the box [x_min, y_min, width, height]
    x_min, y_min, x_max, y_max = cords
    width = x_max - x_min
    height = y_max - y_min

    # Create a Rectangle patch
    rect = patches.Rectangle((x_min, y_min), width, height, linewidth=1, edgecolor='r', facecolor='none')

    # Add the patch to the Axes
    ax.add_patch(rect)

    # Classify object as bio-degradable or non-biodegradable
    if class_id in biodegradable_classes:
        category = 'Bio-degradable'
    elif class_id in non_biodegradable_classes:
        category = 'Non-biodegradable'
    else:
        category = 'Unknown'

    # Show object category and confidence score
    ax.text(x_min, y_min, f"{category} ({conf})", color='r', verticalalignment='top')

# Show plot
plt.show()
